# %% [markdown]
# <a href="https://colab.research.google.com/github/JBonilla00/Core-_Assignments/blob/main/AverageHeightExc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Avarage Height Excercise
#
# Jesse Bonilla

# %% [markdown]
# 03/07/2022

# %% [markdown]
# * Load dataset

# %%
# How many rows
# How many columns
# Which columns have missing values?
# How many entries correspond to the city of London?
# What age is the youngest athlete in out sample data?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
filename = '/content/athleteEventsNoPersonal (1).csv'
df = pd.read_csv(filename)
df
# Out:
#            ID   Age  Height         Team  NOC        Games  Year  Season  \
# 0           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 1           5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter
# 2           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 3           5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter
# 4           5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter
# ...       ...   ...     ...          ...  ...          ...   ...     ...
# 40611  135567  28.0   183.0       Russia  RUS  2004 Summer  2004  Summer
# 40612  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40613  135570  27.0   176.0       Poland  POL  2014 Winter  2014  Winter
# 40614  135571  30.0   185.0       Poland  POL  1998 Winter  1998  Winter
# 40615  135571  34.0   185.0       Poland  POL  2002 Winter  2002  Winter
#
#                  City          Sport  \
# 0             Calgary  Speed Skating
# ...

# %%
# a. 40616 rows
# b. 12 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40616 entries, 0 to 40615
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      40616 non-null  int64
#  1   Age     39143 non-null  float64
#  2   Height  31615 non-null  float64
#  3   Team    40616 non-null  object
#  4   NOC     40616 non-null  object
#  5   Games   40616 non-null  object
#  6   Year    40616 non-null  int64
#  7   Season  40616 non-null  object
#  8   City    40616 non-null  object
#  9   Sport   40616 non-null  object
#  10  Event   40616 non-null  object
#  11  Medal   5917 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.7+ MB

# %%
df['Age'].isna().sum()
# Out:
# 1473

# %%
# c. Age, Height, and Medal

# %%
df['City'].value_counts()
# Out:
# London                    3370
# Athina                    2325
# Beijing                   2056
# Sydney                    2049
# Atlanta                   2037
# Rio de Janeiro            2037
# Barcelona                 1973
# Los Angeles               1864
# Seoul                     1852
# Munich                    1525
# Helsinki                  1305
# Roma                      1259
# Montreal                  1253
# Mexico City               1146
# Moskva                    1116
# Tokyo                     1087
# Paris                     1064
# Berlin                     907
# Sochi                      787
# Amsterdam                  757
# Torino                     687
# Vancouver                  673
# Melbourne                  670
# Antwerpen                  645
# Salt Lake City             639
# Stockholm                  600
# Nagano                     586
# Albertville                545
# Lillehammer                541
# Innsbruck                  504
# ...

# %%
# d. 3370 entries

# %%
df['Age'].min()
# Out:
# 11.0

# %%
# e. 11 is the age of the youngest athlete

# %% [markdown]
# * Create filters to find out:

# %%
# How many athletes who participated in the Sport "Tug-Of-War" were from Team "Sweden" in our sample dataset?
# How many Gold medals were awarded to athletes who were over 40 years old?

# %%
sweden_filter = df['Team'] == "Sweden"
sweden_filter.value_counts()
# Out:
# False    39484
# True      1132
# Name: Team, dtype: int64

# %%
tugwar_filter = df['Sport'] == "Tug-Of-War"
tugwar_filter.value_counts()
# Out:
# False    40598
# True        18
# Name: Sport, dtype: int64

# %%
Participantsswd = df.loc[sweden_filter & tugwar_filter,];
Participantsswd
# Out:
#           ID   Age  Height    Team  NOC        Games  Year  Season    City  \
# 10023  34205  22.0     NaN  Sweden  SWE  1908 Summer  1908  Summer  London
# 12681  43105  23.0     NaN  Sweden  SWE  1906 Summer  1906  Summer  Athina
# 13015  44087  29.0   182.0  Sweden  SWE  1906 Summer  1906  Summer  Athina
# 16250  55169  23.0     NaN  Sweden  SWE  1908 Summer  1908  Summer  London
# 19048  64266  21.0     NaN  Sweden  SWE  1908 Summer  1908  Summer  London
# 20550  68647  26.0   190.0  Sweden  SWE  1906 Summer  1906  Summer  Athina
#
#             Sport                        Event   Medal
# 10023  Tug-Of-War  Tug-Of-War Men's Tug-Of-War     NaN
# 12681  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  Bronze
# 13015  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  Bronze
# 16250  Tug-Of-War  Tug-Of-War Men's Tug-Of-War     NaN
# 19048  Tug-Of-War  Tug-Of-War Men's Tug-Of-War     NaN
# 20550  Tug-Of-War  Tug-Of-War Men's Tug-Of-War  Bronze

# %%
# 2.a 6 Sweden participants were in the sport of Tug of War

# %%
age_filter = df['Age']>40
age_filter.value_counts()
# Out:
# False    39413
# True      1203
# Name: Age, dtype: int64

# %%
swd_gold = df['Medal'].str.contains('Gold')
swd_gold
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 40611    NaN
# 40612    NaN
# 40613    NaN
# 40614    NaN
# 40615    NaN
# Name: Medal, Length: 40616, dtype: object

# %%
award40 = df.loc[swd_gold & age_filter]
award40
# Out:
#            ID   Age  Height                Team  NOC        Games  Year  \
# 740      2735  41.0   168.0              Russia  RUS  2000 Summer  2000
# 1103     4029  46.0     NaN           Argentina  ARG  1936 Summer  1936
# 1421     4993  41.0   180.0             Mosk II  NOR  1920 Summer  1920
# 3040    10769  49.0   180.0          White Lady  DEN  1964 Summer  1964
# 3270    11617  44.0     NaN             Heroine  GBR  1908 Summer  1908
# ...       ...   ...     ...                 ...  ...          ...   ...
# 38916  130271  43.0     NaN            Heira II  NOR  1920 Summer  1920
# 38952  130381  42.0   167.0       United States  USA  1972 Summer  1972
# 39193  130936  56.0     NaN       United States  USA  1908 Summer  1908
# 39197  130936  60.0     NaN       United States  USA  1912 Summer  1912
# 39365  131533  58.0     NaN  Cincinnati Archers  USA  1904 Summer  1904
#
#        Season       City             Sport  \
# 740    Summer     Sydney          Shooting
# ...

# %%
# 2.b 66 participants recieced gold medals

# %% [markdown]
# * Determine the avarage height of:

# %%
# All rows included 
# All rows included, but grouped by Event

# %%
Pheight = df['Height'] = df['Height'].fillna(df['Height'].median())
Pheight
# Out:
# 0        185.0
# 1        185.0
# 2        185.0
# 3        185.0
# 4        185.0
#          ...
# 40611    183.0
# 40612    176.0
# 40613    176.0
# 40614    185.0
# 40615    185.0
# Name: Height, Length: 40616, dtype: float64

# %%
mean_height = df['Height'].mean()
mean_height
# Out:
# 175.29665649005318

# %%
# 3.a 175 is the avarage weight

# %%
df.groupby(['ID','Age','Team','NOC','Games','Year','Season','City','Sport','Medal'])[['Event']]
df.head(40)
# Out:
#     ID   Age  Height           Team  NOC        Games  Year  Season  \
# 0    5  21.0   185.0    Netherlands  NED  1988 Winter  1988  Winter
# 1    5  21.0   185.0    Netherlands  NED  1988 Winter  1988  Winter
# 2    5  25.0   185.0    Netherlands  NED  1992 Winter  1992  Winter
# 3    5  25.0   185.0    Netherlands  NED  1992 Winter  1992  Winter
# 4    5  27.0   185.0    Netherlands  NED  1994 Winter  1994  Winter
# 5    5  27.0   185.0    Netherlands  NED  1994 Winter  1994  Winter
# 6    6  31.0   188.0  United States  USA  1992 Winter  1992  Winter
# 7    6  31.0   188.0  United States  USA  1992 Winter  1992  Winter
# 8    6  31.0   188.0  United States  USA  1992 Winter  1992  Winter
# 9    6  31.0   188.0  United States  USA  1992 Winter  1992  Winter
# 10   6  33.0   188.0  United States  USA  1994 Winter  1994  Winter
# 11   6  33.0   188.0  United States  USA  1994 Winter  1994  Winter
# 12   6  33.0   188.0  United States  USA  1994 Winter  1994  Winter
# ...

# %%
# Bonus: This dataset contains many athletes more than once (if they competed in multiple events and/or multiple years). You can confirm this by finding  .value_counts on the ID column!  For the bonus task we want to get the average height of all  the athletes, but don't want to include any athlete more than once.  Hint: We learned how to drop duplicates if EVERY column was identical, but now we want to drop a row any time just the ID is repeated.  To do this,  you can use a subset of your data as an argument in the drop_duplicates function.  You can also tell Python which of the duplicates to keep by using the keep argument.
